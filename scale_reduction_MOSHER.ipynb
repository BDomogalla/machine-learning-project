# %%
import pandas as pd

# %%
df = pd.read_csv("Data/responses.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
# 5    5.0                       3.0    2.0   3.0      2.0              3.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1      2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2      5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 4      3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
# 5      3.0  2.0   5.0                5.0  ...  20.0   186.0    77.0
#
#    Number of siblings  Gender  Left - right handed                Education  \
# ...

# %%
df_adjusted = df.replace(2, 1)

# %%
df_adjusted = df_adjusted.replace(3, 2)

# %%
df_adjusted = df_adjusted.replace(4, 3)

# %%
df_adjusted = df_adjusted.replace(5, 3)

# %%
df_adjusted.to_csv('Data/responses_adjusted_scale_MOSHER.csv', index=False)

# %%
personality_traits_adjusted = df_adjusted[['Gender', 'Education', 'Heights', 'Spiders', 'Snakes',
                                           'Fear of public speaking', 'Ageing', 'Smoking', 'Alcohol', 
                                           'Healthy eating', 'Daily events', 'Prioritising workload',
                                           'Writing notes', 'Workaholism', 'Thinking ahead', 'Final judgement',
                                           'Reliability', 'Keeping promises', 'Loss of interest', 
                                           'Friends versus money', 'Funniness', 'Fake', 'Criminal damage', 
                                           'Decision making', 'Elections', 'Self-criticism', 'Judgment calls',
                                           'Hypochondria', 'Empathy', 'Eating to survive', 'Giving', 
                                           'Compassion to animals', 'Borrowed stuff', 'Loneliness', 
                                           'Cheating in school', 'Health', 'Changing the past', 'God',
                                           'Dreams', 'Charity', 'Number of friends', 'Waiting', 'New environment',
                                           'Mood swings', 'Appearence and gestures', 'Socializing', 'Achievements',
                                           'Responding to a serious letter', 'Children', 'Assertiveness',
                                           'Getting angry', 'Knowing the right people', 'Public speaking', 
                                           'Unpopularity', 'Life struggles', 'Happiness in life', 'Energy levels',
                                           'Small - big dogs', 'Personality', 'Finding lost valuables', 'Getting up',
                                           'Interests or hobbies', "Parents' advice", 'Questionnaires or polls']]

# %%
personality_traits_adjusted = personality_traits_adjusted.replace({'Heights': 1, 'Spiders': 1, 'Snakes': 1, 
                                                                   'Fear of public speaking': 1, 'Ageing': 1}, 
                                                                  "Not afraid")

# %%
personality_traits_adjusted = personality_traits_adjusted.replace({'Heights': 2, 'Spiders': 2, 'Snakes': 2, 
                                                                   'Fear of public speaking': 2, 'Ageing': 2}, 
                                                                  "Neutral")

# %%
personality_traits_adjusted = personality_traits_adjusted.replace({'Heights': 3, 'Spiders': 3, 'Snakes': 3, 
                                                                   'Fear of public speaking': 3, 'Ageing': 3}, 
                                                                  "Afraid")

# %%
personality_traits_adjusted
# Out:
#       Gender                Education     Heights     Spiders      Snakes  \
# 0     female  college/bachelor degree  Not afraid  Not afraid      Afraid
# 1     female  college/bachelor degree  Not afraid  Not afraid  Not afraid
# 2     female         secondary school  Not afraid  Not afraid  Not afraid
# 4     female         secondary school  Not afraid  Not afraid  Not afraid
# 5       male         secondary school  Not afraid  Not afraid  Not afraid
# ...      ...                      ...         ...         ...         ...
# 1004    male         secondary school     Neutral     Neutral  Not afraid
# 1005  female         secondary school      Afraid  Not afraid  Not afraid
# 1007  female         secondary school  Not afraid  Not afraid  Not afraid
# 1008  female  college/bachelor degree      Afraid     Neutral     Neutral
# 1009    male         secondary school      Afraid  Not afraid      Afraid
#
#      Fear of public speaking      Ageing         Smoking         Alcohol  \
# ...

# %%
personality_traits_adjusted.to_csv('Data/personality_traits_adjusted_scale_MOSHER.csv', index=False)
