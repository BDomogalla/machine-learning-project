# %% [markdown]
# http://blog.yhat.com/posts/logistic-regression-and-python.html

# %%
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np

# %%
df = pd.read_csv("Data/responses.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
# 5    5.0                       3.0    2.0   3.0      2.0              3.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1      2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2      5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 4      3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
# 5      3.0  2.0   5.0                5.0  ...  20.0   186.0    77.0
#
#    Number of siblings  Gender  Left - right handed                Education  \
# 0                 1.0  female         right handed  college/bachelor degree
# 1                 2.0  female         right handed  college/bachelor degree
# 2                 2.0  female         right handed         secondary school
# 4                 1.0  female         right handed         secondary school
# 5                 1.0    male         right handed         secondary school
#
#    Only child  Village - town  House - block of flats
# 0          no         village          block of flats
# 1          no            city          block of flats
# 2          no            city          block of flats
# 4          no         village          house/bungalow
# 5          no            city          block of flats
#
# [5 rows x 150 columns]

# %%
print (df.describe())
# Out:
#             Music  Slow songs or fast songs       Dance        Folk  \
# count  674.000000                674.000000  674.000000  674.000000
# mean     4.762611                  3.295252    3.078635    2.264095
# std      0.594699                  0.795833    1.179841    1.120517
# min      1.000000                  1.000000    1.000000    1.000000
# 25%      5.000000                  3.000000    2.000000    1.000000
# 50%      5.000000                  3.000000    3.000000    2.000000
# 75%      5.000000                  4.000000    4.000000    3.000000
# max      5.000000                  5.000000    5.000000    5.000000
#
#           Country  Classical music     Musical         Pop        Rock  \
# count  674.000000       674.000000  674.000000  674.000000  674.000000
# mean     2.117211         2.982196    2.759644    3.451039    3.787834
# std      1.063888         1.244176    1.281403    1.165938    1.152979
# min      1.000000         1.000000    1.000000    1.000000    1.000000
# 25%      1.000000         2.000000    2.000000    3.000000    3.000000
# 50%      2.000000         3.000000    3.000000    4.000000    4.000000
# 75%      3.000000         4.000000    4.000000    4.000000    5.000000
# max      5.000000         5.000000    5.000000    5.000000    5.000000
#
#        Metal or Hardrock  ...  Shopping centres  Branded clothing  \
# count         674.000000  ...        674.000000        674.000000
# mean            2.354599  ...          3.258160          3.026706
# std             1.396371  ...          1.305537          1.305787
# min             1.000000  ...          1.000000          1.000000
# 25%             1.000000  ...          2.000000          2.000000
# 50%             2.000000  ...          3.000000          3.000000
# 75%             3.000000  ...          4.000000          4.000000
# max             5.000000  ...          5.000000          5.000000
#
#        Entertainment spending  Spending on looks  Spending on gadgets  \
# count              674.000000         674.000000           674.000000
# mean                 3.191395           3.096439             2.850148
# std                  1.180771           1.208398             1.299140
# min                  1.000000           1.000000             1.000000
# 25%                  2.000000           2.000000             2.000000
# 50%                  3.000000           3.000000             3.000000
# 75%                  4.000000           4.000000             4.000000
# max                  5.000000           5.000000             5.000000
#
#        Spending on healthy eating         Age      Height      Weight  \
# count                  674.000000  674.000000  674.000000  674.000000
# mean                     3.514837   20.353116  173.419881   66.117211
# std                      1.076806    2.732763    9.475720   13.900289
# min                      1.000000   15.000000  152.000000   41.000000
# 25%                      3.000000   19.000000  167.000000   55.000000
# 50%                      4.000000   20.000000  172.000000   63.000000
# 75%                      4.000000   21.000000  180.000000   75.000000
# max                      5.000000   30.000000  203.000000  150.000000
#
#        Number of siblings
# count          674.000000
# mean             1.299703
# std              0.992887
# min              0.000000
# 25%              1.000000
# 50%              1.000000
# 75%              2.000000
# max             10.000000
#
# [8 rows x 139 columns]

# %%
print (df.std())
# Out:
# Music                              0.594699
# Slow songs or fast songs           0.795833
# Dance                              1.179841
# Folk                               1.120517
# Country                            1.063888
# Classical music                    1.244176
# Musical                            1.281403
# Pop                                1.165938
# Rock                               1.152979
# Metal or Hardrock                  1.396371
# Punk                               1.290428
# Hiphop, Rap                        1.345403
# Reggae, Ska                        1.207882
# Swing, Jazz                        1.259179
# Rock n roll                        1.205514
# Alternative                        1.336017
# Latino                             1.318767
# Techno, Trance                     1.308924
# Opera                              1.193528
# Movies                             0.658006
# Horror                             1.385832
# Thriller                           1.185142
# Comedy                             0.745817
# Romantic                           1.203029
# Sci-fi                             1.302803
# War                                1.334795
# Fantasy/Fairy tales                1.180614
# Animated                           1.213800
# Documentary                        1.114682
# Western                            1.112097
#                                     ...
# Socializing                        1.107592
# Achievements                       0.912173
# Responding to a serious letter     1.176619
# Children                           1.133926
# Assertiveness                      1.103719
# Getting angry                      1.155764
# Knowing the right people           1.112648
# Public speaking                    1.275070
# Unpopularity                       1.143008
# Life struggles                     1.384954
# Happiness in life                  0.824818
# Energy levels                      1.016971
# Small - big dogs                   1.200412
# Personality                        0.631233
# Finding lost valuables             1.248796
# Getting up                         1.291651
# Interests or hobbies               1.190910
# Parents' advice                    0.836164
# Questionnaires or polls            1.080709
# Finances                           1.152279
# Shopping centres                   1.305537
# Branded clothing                   1.305787
# Entertainment spending             1.180771
# Spending on looks                  1.208398
# Spending on gadgets                1.299140
# Spending on healthy eating         1.076806
# Age                                2.732763
# Height                             9.475720
# Weight                            13.900289
# Number of siblings                 0.992887
# Length: 139, dtype: float64

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BB4B4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BDBBC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BB85278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BBD6828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BC6BDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BCA43C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BCD1978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BD01F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BD01F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11BFD8AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C0130B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C041668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C073C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C0AF208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C0DF7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C114D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C14D208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C17D7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C1AFD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C1EC358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C21B908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C251EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C28C4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C2BCA58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C2FA048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C32A5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C35CBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C39A198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C3C9748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C3FCCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C4382E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C467898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C49BE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C4D7438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C5099E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C53BF98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C576588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C5A7B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C5E6128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C6156D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C646C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C685278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C6B3828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C6E7DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C7253C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C754978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C786F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C7C3518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C7F3AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C8300B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C861668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C894C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C8D1208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C9027B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C934D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C970358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C99E908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11C9D4EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CA0F4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CA3DA58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CA7D048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CAAE5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CADFBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CB1D198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CB4B748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CB7FCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CBBC2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CBEC898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CC1EE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CC5A438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CC8B9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CCBFF98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CCFB588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CD2AB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CD69128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CD9A6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CDC8C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CE07278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CE37828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CE6BDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CEA73C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CED7978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CF0AF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CF45518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CF77AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CFB60B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11CFE5668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D019C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D056208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D0867B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D0B5D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D0F3358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D126908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D156EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D1934A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D1C3A58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D201048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D2315F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D263BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D2A3198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D2D2748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D305CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D3402E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D36F898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D3A2E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D3DE438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D4119E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D443F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D47E588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D4AEB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D4EE128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D51D6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D54EC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D58C278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D5BB828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D5F0DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D62D3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D65D978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D690F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D6CB518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D6FCAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11D73C0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E73A668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E769C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E7AA208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E7D97B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E808D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E849358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E877908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E8A8EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E8E74A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E918A58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E955048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E9875F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E9B8BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11E9F4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11EA23748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11EA57CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11EA942E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11EAC4898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11EAF5E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11EB32438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11EB639E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B11EB95F98>]],
#       dtype=object)

# %%
pl.show()

# %%
selected_features = df[['Health']]

# %%
train_cols = df[['Health']]

# %%
logit = sm.Logit(data['Gender'], data[train_cols])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ecbc624cd312> in <module>
# ----> 1 logit = sm.Logit(data['Gender'], data[train_cols])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2912         # Do we have a (boolean) DataFrame?
#    2913         if isinstance(key, DataFrame):
# -> 2914             return self._getitem_frame(key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    3007     def _getitem_frame(self, key):
#    3008         if key.values.size and not is_bool_dtype(key.values):
# -> 3009             raise ValueError('Must pass DataFrame with boolean values only')
#    3010         return self.where(key)
#    3011
#
# ValueError: Must pass DataFrame with boolean values only

# %%
result = logit.fit()

# %%
print result.summary()

# %%
print result.conf_int()
