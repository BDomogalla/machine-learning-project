# %%
# Import Modules and Dependencies
import pandas as pd
import os

# %%
# Read in CSV File Containing Raw Dataset
df = pd.read_csv("Data/responses.csv")

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# %%
# Remove All Unwanted Columns From the Dataset
df_filtered = df[["Gender", "Education", "Heights", "Spiders", "Snakes", "Fear of public speaking", "Ageing", "Smoking",
                  "Alcohol", "Healthy eating", "Daily events", "Prioritising workload", "Writing notes",
                  "Workaholism", "Thinking ahead", "Final judgement", "Reliability", "Keeping promises", "Loss of interest",
                  "Friends versus money", "Funniness", "Fake", "Criminal damage", "Decision making", "Elections",
                  "Self-criticism", "Judgment calls", "Hypochondria", "Empathy", "Eating to survive", "Giving",
                  "Compassion to animals", "Borrowed stuff", "Loneliness", "Cheating in school", "Health", "Changing the past",
                  "God", "Dreams", "Charity", "Number of friends", "Waiting", "New environment", "Mood swings",
                  "Appearence and gestures", "Socializing", "Achievements", "Responding to a serious letter", "Children",
                  "Assertiveness", "Getting angry", "Knowing the right people", "Public speaking", "Unpopularity",
                  "Life struggles", "Happiness in life", "Energy levels", "Small - big dogs", "Personality",
                  "Finding lost valuables", "Getting up", "Interests or hobbies", "Parents' advice", "Questionnaires or polls"]]

# %%
# View Filtered DataFrame
df_filtered.head()
# Out:
#    Gender                Education  Heights  Spiders  Snakes  \
# 0  female  college/bachelor degree      1.0      1.0       5
# 1  female  college/bachelor degree      2.0      1.0       1
# 2  female         secondary school      1.0      1.0       1
# 4  female         secondary school      1.0      1.0       1
# 5    male         secondary school      2.0      1.0       2
#
#    Fear of public speaking  Ageing        Smoking         Alcohol  \
# 0                      2.0     1.0   never smoked     drink a lot
# 1                      4.0     3.0   never smoked     drink a lot
# 2                      2.0     1.0  tried smoking     drink a lot
# 4                      3.0     2.0  tried smoking  social drinker
# 5                      3.0     1.0   never smoked           never
#
#    Healthy eating  ...  Life struggles  Happiness in life  Energy levels  \
# 0             4.0  ...             1.0                4.0            5.0
# ...

# %%
# Save Filtered DataFrame to a CSV File
df_filtered.to_csv("Data/personality_traits.csv", header=True, index=False)
