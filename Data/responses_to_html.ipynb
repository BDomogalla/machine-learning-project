# %%
import pandas as pd

# %%
data = pd.read_csv("prediction_results.csv")

# %%
data.set_index('Code Name', inplace=True)

# %%
data
# Out:
#                          Gender          Education Level Snake Phobia  \
# Code Name
# Missy Elliot             female         secondary school       Afraid
# Wheezer                    male         secondary school       Afraid
# NANANANANAN                male         secondary school       Afraid
# Rubber Ducky               male         secondary school   Not Afraid
# John Doe                   male         secondary school       Afraid
# im not feeling creative    male  college/bachelor degree       Afraid
# Trisk                    female         secondary school       Afraid
# XST222                   female         secondary school       Afraid
# Frogs are the best       female         secondary school   Not Afraid
# Batman                   female         secondary school   Not Afraid
# Cazman1986                 male         secondary school       Afraid
# Ivan Waterman              male  college/bachelor degree       Afraid
# ...

# %%
html= data.to_html()

# %%
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Gender</th>
#       <th>Education Level</th>
#       <th>Snake Phobia</th>
#       <th>Spider Phobia</th>
#       <th>Heights Phobia</th>
#     </tr>
#     <tr>
#       <th>Code Name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Missy Elliot</th>
#       <td>female</td>
#       <td>secondary school</td>
#       <td>Afraid</td>
#       <td>Not afraid</td>
#       <td>Afraid</td>
#     </tr>
#     <tr>
#       <th>Wheezer</th>
#       <td>male</td>
#       <td>secondary school</td>
#       <td>Afraid</td>
#       <td>Not afraid</td>
#       <td>Not afraid</td>
#     </tr>
#     <tr>
#       <th>NANANANANAN</th>
#       <td>male</td>
#       <td>secondary school</td>
#       <td>Afraid</td>
#       <td>Not afraid</td>
#       <td>Afraid</td>
#     </tr>
#     <tr>
# ...
